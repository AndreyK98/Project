# %%
pip install -U pymorphy2-dicts-ru
# Out:
# Collecting pymorphy2-dicts-ru
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ---------------------------------------- 8.2/8.2 MB 15.4 MB/s eta 0:00:00
# Installing collected packages: pymorphy2-dicts-ru
# Successfully installed pymorphy2-dicts-ru-2.4.417127.4579844
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing requirements for suitesparse-graphblas: [Errno 2] No such file or directory: 'c:\\users\\andrey.kalachikhin\\appdata\\local\\anaconda3\\lib\\site-packages\\suitesparse_graphblas-8.2.1.0.dist-info\\METADATA'

# %%
pip install pymorphy2
# Out:
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      -------------------------------------- 55.5/55.5 kB 962.6 kB/s eta 0:00:00
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\andrey.kalachikhin\appdata\local\anaconda3\lib\site-packages (from pymorphy2) (2.4.417127.4579844)
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=67cd6f79107018fc8b2e84cd675cfa53185e310b6f5ebf5d87acc3c4627da511
#   Stored in directory: c:\users\andrey.kalachikhin\appdata\local\pip\cache\wheels\7c\d7\8d\2156234738063e3d4a39ba77dc677046100e62766b53807189
# Successfully built docopt
# Installing collected packages: docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing requirements for suitesparse-graphblas: [Errno 2] No such file or directory: 'c:\\users\\andrey.kalachikhin\\appdata\\local\\anaconda3\\lib\\site-packages\\suitesparse_graphblas-8.2.1.0.dist-info\\METADATA'

# %%
pip install natasha
# Out:
# Collecting natasha
#   Downloading natasha-1.6.0-py3-none-any.whl (34.4 MB)
#      --------------------------------------- 34.4/34.4 MB 36.4 MB/s eta 0:00:00
# Collecting ipymarkup>=0.8.0
#   Downloading ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Collecting razdel>=0.5.0
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Collecting yargy>=0.16.0
#   Downloading yargy-0.16.0-py3-none-any.whl (33 kB)
# Collecting navec>=0.9.0
#   Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: pymorphy2 in c:\users\andrey.kalachikhin\appdata\local\anaconda3\lib\site-packages (from natasha) (0.9.1)
# Collecting slovnet>=0.6.0
#   Downloading slovnet-0.6.0-py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.7/46.7 kB ? eta 0:00:00
# Requirement already satisfied: intervaltree>=3 in c:\users\andrey.kalachikhin\appdata\local\anaconda3\lib\site-packages (from ipymarkup>=0.8.0->natasha) (3.1.0)
# Requirement already satisfied: numpy in c:\users\andrey.kalachikhin\appdata\local\anaconda3\lib\site-packages (from navec>=0.9.0->natasha) (1.23.5)
# Requirement already satisfied: docopt>=0.6 in c:\users\andrey.kalachikhin\appdata\local\anaconda3\lib\site-packages (from pymorphy2->natasha) (0.6.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\andrey.kalachikhin\appdata\local\anaconda3\lib\site-packages (from pymorphy2->natasha) (2.4.417127.4579844)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\andrey.kalachikhin\appdata\local\anaconda3\lib\site-packages (from pymorphy2->natasha) (0.7.2)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\users\andrey.kalachikhin\appdata\local\anaconda3\lib\site-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha) (2.4.0)
# Installing collected packages: razdel, navec, yargy, slovnet, ipymarkup, natasha
# Successfully installed ipymarkup-0.9.0 natasha-1.6.0 navec-0.10.0 razdel-0.5.0 slovnet-0.6.0 yargy-0.16.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing requirements for suitesparse-graphblas: [Errno 2] No such file or directory: 'c:\\users\\andrey.kalachikhin\\appdata\\local\\anaconda3\\lib\\site-packages\\suitesparse_graphblas-8.2.1.0.dist-info\\METADATA'

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

from nltk import stem
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

from string import punctuation
import pymorphy2

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MiniBatchKMeans
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

from natasha import (
    Segmenter,
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    MorphVocab,
    PER,
    NamesExtractor,
    Doc
)

from yargy import Parser, rule
from yargy.predicates import gram, dictionary

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df = pd.read_excel('/itsm_incident.xlsx')
df
# Out:
#            Номер                                               Тема  \
# 0     INC0005659  Утром опять завис и рестартнул контейнер аттач...
# 1     INC0005658   Задержка в выборке писем из ящика после простоев
# 2     INC0005657            Проблема с отображением Related Tickets
# 3     INC0005656  Некорректное отображение кнопок UI-action на ф...
# 4     INC0005655                         GRPC Server is unavailable
# ...          ...                                                ...
# 1474  INC0003655        Восстановление доступа на home.simpleone.ru
# 1475  INC0003654     Исходящее письмо обработано со статусом Failed
# 1476  INC0003653  Исходящее письмо обработано со статусом Failed...
# 1477  INC0003652                             Уязвимость на инстансе
# 1478  INC0003649  На продакшн-инстансе, перестали регистрировать...
#
#      Краткое описание        Статус  Приоритет  SLA нарушено  \
# 0                 NaN        Закрыт  Критичный         False
# 1                 NaN  В разработке    Высокий         False
# 2                 NaN        Закрыт    Высокий         False
# 3                 NaN        Закрыт     Низкий         False
# 4                 NaN  В разработке    Высокий         False
# ...               ...           ...        ...           ...
# 1474              NaN        Закрыт     Низкий         False
# 1475              NaN        Закрыт    Средний         False
# 1476              NaN        Закрыт    Высокий         False
# 1477              NaN        Закрыт    Высокий         False
# 1478              NaN        Закрыт  Критичный         False
#
#       Инфраструктурный инцидент
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 1474                      False
# 1475                       True
# 1476                       True
# 1477                      False
# 1478                       True
#
# [1479 rows x 7 columns]

# %%
df = df[['Тема']]
df
# Out:
#                                                    Тема
# 0     Утром опять завис и рестартнул контейнер аттач...
# 1      Задержка в выборке писем из ящика после простоев
# 2               Проблема с отображением Related Tickets
# 3     Некорректное отображение кнопок UI-action на ф...
# 4                            GRPC Server is unavailable
# ...                                                 ...
# 1474        Восстановление доступа на home.simpleone.ru
# 1475     Исходящее письмо обработано со статусом Failed
# 1476  Исходящее письмо обработано со статусом Failed...
# 1477                             Уязвимость на инстансе
# 1478  На продакшн-инстансе, перестали регистрировать...
#
# [1479 rows x 1 columns]

# %%
lemma = pymorphy2.MorphAnalyzer()
russian_stopwords = stopwords.words("russian")

# %%
def preprocess(doc: str):
    # чтобы аббревиатуры через дефис (например,  SAS-источник) не склеились
    doc = doc.replace('-', ' ')
    stop_free = " ".join([i for i in doc.lower().split() if i not in russian_stopwords])
    punc_free = ''.join(ch for ch in stop_free if ch not in punctuation)
    text = " ".join([lemma.parse(word)[0].normal_form for word in punc_free.split(' ')])
    return text

# %%
df['stem'] = df['Тема'].apply(preprocess)

# %%
df
# Out:
#                                                    Тема  \
# 0     Утром опять завис и рестартнул контейнер аттач...
# 1      Задержка в выборке писем из ящика после простоев
# 2               Проблема с отображением Related Tickets
# 3     Некорректное отображение кнопок UI-action на ф...
# 4                            GRPC Server is unavailable
# ...                                                 ...
# 1474        Восстановление доступа на home.simpleone.ru
# 1475     Исходящее письмо обработано со статусом Failed
# 1476  Исходящее письмо обработано со статусом Failed...
# 1477                             Уязвимость на инстансе
# 1478  На продакшн-инстансе, перестали регистрировать...
#
#                                                    stem
# 0     утром зависнуть рестартнуть контейнер аттач pr...
# 1                  задержка выборка письмо ящик простой
# 2                  проблема отображение related tickets
# 3     некорректный отображение кнопка ui action форм...
# 4                            grpc server is unavailable
# ...                                                 ...
# 1474              восстановление доступ homesimpleoneru
# 1475          исходящий письмо обработать статус failed
# 1476  исходящий письмо обработать статус failed запи...
# 1477                                 уязвимость инстанс
# 1478  продакшн инстанс перестать регистрироваться за...
#
# [1479 rows x 2 columns]

# %% [markdown]
# # Кластеризация

# %% [markdown]
# Векторизуем наши наборы запросов.

# %%
vectorizer = TfidfVectorizer(smooth_idf=True, max_df=0.6, min_df=0.01, max_features=100000, use_idf=True, ngram_range=(1,3), decode_error='ignore')
tfidf_matrix = vectorizer.fit_transform(df['stem'])

# %% [markdown]
# ## MiniBatchKMeans
#
# Полученное векторизованное представление кластеризуем. Воспользуемся методом MiniBatchKMeans.

# %% [markdown]
# Выберем число кластеров по графику каменистая осыпь (локоть). Построим график зависимости расстояний между кластерами от шага слияния, и посмотрим, когда это расстояние перестанет значительно меняться.

# %%
K = range(1, 40)
models = [MiniBatchKMeans(n_clusters=k, random_state=42, init='random').fit(tfidf_matrix) for k in K]

#качество кластеризации в model.inertia_
dist = [model.inertia_ for model in models]

plt.plot(K, dist, marker='o')
plt.xlabel('k')
plt.ylabel('Sum of distances')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# Виден излом на количестве 3 13 19 кластеров.

# %%
cluster_number_k_means = 13

# %%
k_means_batch = MiniBatchKMeans(n_clusters=cluster_number_k_means, init='random').fit(tfidf_matrix)
labels_k_means_batch = k_means_batch.predict(tfidf_matrix)

# %%
df['cluster_k_means'] = labels_k_means_batch
df
# Out:
#                                                    Тема  \
# 0     Утром опять завис и рестартнул контейнер аттач...
# 1      Задержка в выборке писем из ящика после простоев
# 2               Проблема с отображением Related Tickets
# 3     Некорректное отображение кнопок UI-action на ф...
# 4                            GRPC Server is unavailable
# ...                                                 ...
# 1474        Восстановление доступа на home.simpleone.ru
# 1475     Исходящее письмо обработано со статусом Failed
# 1476  Исходящее письмо обработано со статусом Failed...
# 1477                             Уязвимость на инстансе
# 1478  На продакшн-инстансе, перестали регистрировать...
#
#                                                    stem  cluster_k_means
# 0     утром зависнуть рестартнуть контейнер аттач pr...                4
# 1                  задержка выборка письмо ящик простой                4
# 2                  проблема отображение related tickets                4
# 3     некорректный отображение кнопка ui action форм...                4
# 4                            grpc server is unavailable                4
# ...                                                 ...              ...
# 1474              восстановление доступ homesimpleoneru                4
# 1475          исходящий письмо обработать статус failed                4
# 1476  исходящий письмо обработать статус failed запи...                4
# 1477                                 уязвимость инстанс                4
# 1478  продакшн инстанс перестать регистрироваться за...                4
#
# [1479 rows x 3 columns]

# %% [markdown]
# Рассмотрим примеры кластеров:

# %%
df[df.cluster_k_means == 0]
# Out:
#                                                    Тема  \
# 281        🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443
# 469        🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443
# 470        🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443
# 861                         🔥 500 CAN'T CONNECT TO PROD
# 862                         🔥 500 CAN'T CONNECT TO PROD
# 886        🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443
# 887        🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443
# 1125                         🔥 500 CAN'T CONNECT TO DEV
# 1151                        🔥 500 CAN'T CONNECT TO TEST
# 1152                         🔥 500 CAN'T CONNECT TO DEV
# 1153                        🔥 500 CAN'T CONNECT TO PROD
# 1154                         🔥 500 CAN'T CONNECT TO DEV
# 1155                        🔥 500 CAN'T CONNECT TO TEST
# 1156                        🔥 500 CAN'T CONNECT TO PROD
# 1157                         🔥 500 CAN'T CONNECT TO DEV
# 1158                        🔥 500 CAN'T CONNECT TO TEST
# 1159                        🔥 500 CAN'T CONNECT TO PROD
# 1160                        🔥 500 CAN'T CONNECT TO PROD
# 1161                         🔥 500 CAN'T CONNECT TO DEV
# 1162  🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443 (...
# 1163                        🔥 500 CAN'T CONNECT TO TEST
# 1164                         🔥 500 CAN'T CONNECT TO DEV
# 1165                        🔥 500 CAN'T CONNECT TO PROD
# 1166                         🔥 500 CAN'T CONNECT TO DEV
# 1167                        🔥 500 CAN'T CONNECT TO TEST
# 1168                        🔥 500 CAN'T CONNECT TO PROD
# 1169  🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443 (...
# 1170                         🔥 500 CAN'T CONNECT TO DEV
# 1171                        🔥 500 CAN'T CONNECT TO PROD
# 1172                        🔥 500 CAN'T CONNECT TO TEST
# 1173  🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443 (...
# 1174                         🔥 500 CAN'T CONNECT TO DEV
# 1188  🔥 500 CAN'T CONNECT TO SERVICEDESK.ITPARK.RU:4...
# 1191  🔥 500 CAN'T CONNECT TO SERVICEDESK.ITPARK.RU:4...
# 1192  🔥 500 CAN'T CONNECT TO SERVICEDESK.ITPARK.RU:4...
# 1193  🔥 500 CAN'T CONNECT TO SERVICEDESK.ITPARK.RU:4...
# 1195  🔥 500 CAN'T CONNECT TO SERVICEDESK.ITPARK.RU:4...
# 1199  🔥 500 CAN'T CONNECT TO SERVICEDESK.ITPARK.RU:4...
# 1413  🔥 500 CAN'T CONNECT TO SERVICEDESK.RU:443 (NAM...
# 1414  🔥 500 CAN'T CONNECT TO SERVICEDESK.RU:443 (NAM...
# 1415  🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443 (...
# 1416  🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443 (...
# 1417  🔥 500 CAN'T CONNECT TO SERVICEDESK.RU:443 (NAM...
# 1418  🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443 (...
# 1419  🔥 500 CAN'T CONNECT TO SIMPLEONE.RU:443 (NAME ...
# 1420  🔥 500 CAN'T CONNECT TO SERVICEDESK.RU:443 (NAM...
# 1421  🔥 500 CAN'T CONNECT TO SIMPLEONE.RU:443 (NAME ...
# 1422  🔥 500 CAN'T CONNECT TO HOME.SIMPLEONE.RU:443 (...
# 1460                         🔥 500 CAN'T CONNECT TO DEV
#
#                                                    stem  cluster_k_means
# 281            🔥 500 cant connect to homesimpleoneru443                0
# 469            🔥 500 cant connect to homesimpleoneru443                0
# 470            🔥 500 cant connect to homesimpleoneru443                0
# 861                          🔥 500 cant connect to prod                0
# 862                          🔥 500 cant connect to prod                0
# 886            🔥 500 cant connect to homesimpleoneru443                0
# 887            🔥 500 cant connect to homesimpleoneru443                0
# 1125                          🔥 500 cant connect to dev                0
# 1151                         🔥 500 cant connect to test                0
# 1152                          🔥 500 cant connect to dev                0
# 1153                         🔥 500 cant connect to prod                0
# 1154                          🔥 500 cant connect to dev                0
# 1155                         🔥 500 cant connect to test                0
# 1156                         🔥 500 cant connect to prod                0
# 1157                          🔥 500 cant connect to dev                0
# 1158                         🔥 500 cant connect to test                0
# 1159                         🔥 500 cant connect to prod                0
# 1160                         🔥 500 cant connect to prod                0
# 1161                          🔥 500 cant connect to dev                0
# 1162  🔥 500 cant connect to homesimpleoneru443 conne...                0
# 1163                         🔥 500 cant connect to test                0
# 1164                          🔥 500 cant connect to dev                0
# 1165                         🔥 500 cant connect to prod                0
# 1166                          🔥 500 cant connect to dev                0
# 1167                         🔥 500 cant connect to test                0
# 1168                         🔥 500 cant connect to prod                0
# 1169  🔥 500 cant connect to homesimpleoneru443 conne...                0
# 1170                          🔥 500 cant connect to dev                0
# 1171                         🔥 500 cant connect to prod                0
# 1172                         🔥 500 cant connect to test                0
# 1173  🔥 500 cant connect to homesimpleoneru443 conne...                0
# 1174                          🔥 500 cant connect to dev                0
# 1188  🔥 500 cant connect to servicedeskitparkru443 c...                0
# 1191  🔥 500 cant connect to servicedeskitparkru443 c...                0
# 1192  🔥 500 cant connect to servicedeskitparkru443 c...                0
# 1193  🔥 500 cant connect to servicedeskitparkru443 c...                0
# 1195  🔥 500 cant connect to servicedeskitparkru443 c...                0
# 1199  🔥 500 cant connect to servicedeskitparkru443 c...                0
# 1413  🔥 500 cant connect to servicedeskru443 name or...                0
# 1414  🔥 500 cant connect to servicedeskru443 name or...                0
# 1415  🔥 500 cant connect to homesimpleoneru443 name ...                0
# 1416  🔥 500 cant connect to homesimpleoneru443 name ...                0
# 1417  🔥 500 cant connect to servicedeskru443 name or...                0
# 1418  🔥 500 cant connect to homesimpleoneru443 name ...                0
# 1419  🔥 500 cant connect to simpleoneru443 name or s...                0
# 1420  🔥 500 cant connect to servicedeskru443 name or...                0
# 1421  🔥 500 cant connect to simpleoneru443 name or s...                0
# 1422  🔥 500 cant connect to homesimpleoneru443 name ...                0
# 1460                          🔥 500 cant connect to dev                0

# %%
df[df.cluster_k_means == 5]
# Out:
#                                                    Тема  \
# 139                 Не приостанавливается индикация SLA
# 181                                           Индикация
# 255                       Работа календаря на индикации
# 258          Не запускаются индикации на deve и в проде
# 274     SLA. Задержка 2 часа перед созданием индикации.
# 280                              Дублирование индикаций
# 289                  Не создаются индикации на инстансе
# 296                       Некорректная работа индикаций
# 358                  Не создаются индикации на инстансе
# 416                          Позднее создание индикаций
# 721   Икселерейт - индикация не отмечается "нарушенн...
# 732                          Логика пересчета индикаций
# 756   В индикации при просрочке не устанавливается ф...
# 804   Индикация не встает на паузу, хотя попадает по...
# 814                 Не останавливаются индикации по SLM
# 840     Проблема с расчетом параметра Паузы в Индикации
# 856               Не корректное время запуска индикации
# 905   Долго создаются индикации, прошу добавить ворк...
# 1013    Проблема с расчетом параметра Паузы в Индикации
# 1026  Не завершаются некоторые индикации на инстансе...
# 1090                              Дублируются индикации
# 1203                  Постоянные проблемы с индикациями
# 1225     Не создаются индикации по активным индикаторам
# 1271                      Некорректная работа индикации
#
#                                                    stem  cluster_k_means
# 139                    приостанавливаться индикация sla                5
# 181                                           индикация                5
# 255                          работа календарь индикация                5
# 258                    запускаться индикация deve продя                5
# 274               sla задержка 2 час создание индикация                5
# 280                              дублирование индикация                5
# 289                       создаваться индикация инстанс                5
# 296                       некорректный работа индикация                5
# 358                       создаваться индикация инстанс                5
# 416                          поздний создание индикация                5
# 721   икселерейт индикация отмечаться нарушить дости...                5
# 732                           логика пересчёт индикация                5
# 756   индикация просрочка устанавливаться флаг нарушить                5
# 804      индикация вставать пауза хотя попадать условие                5
# 814                       останавливаться индикация slm                5
# 840            проблема расчёт параметр пауза индикация                5
# 856                   корректный время запуск индикация                5
# 905   долго создаваться индикация просить добавить в...                5
# 1013           проблема расчёт параметр пауза индикация                5
# 1026   завершаться некоторый индикация инстанс заказчик                5
# 1090                            дублироваться индикация                5
# 1203                      постоянный проблема индикация                5
# 1225           создаваться индикация активный индикатор                5
# 1271                      некорректный работа индикация                5

# %%
df[df.cluster_k_means == 10]
# Out:
#                                                    Тема  \
# 25    Инстенс: demo Ошибка при настройки формы предс...
# 69    Портал. Каталог услуг. Проблема с клиентскими ...
# 161          Формирование обращения через Каталог услуг
# 173   "Обрезка" половины строки в карточках каталога...
# 397                     Не работает фильтрация каталога
# 513   Долго открывается боковое меню при переходе по...
# 539            Не открывается каталог услуг, ошибка 504
# 642                   Медленное открытие каталога услуг
# 735   LDAP авторизация S1 через LDAP каталоги отличн...
# 857                  Ошибка в переходе в Каталоге Услуг
# 903   Долгое появление категории в каталоге услуг sc...
# 916   Дефекс верстки карточки услуги (модели запроса...
# 927   На портале в каталоге услуг не работает стрелк...
# 932   Очень медленно отображается портал конечного п...
# 1012  Ошибка "Поле ""Номер" [number]" должно быть ун...
# 1044  Нет возможности выбирать ресурс на странице по...
# 1316  Проблема при переключении категорий в каталоге...
# 1346  Пользователь не видит параметры REM в зарегист...
# 1347                Каталог услуг на базе REM + Inquiry
# 1462  Возникает предупреждение при выборе другого ти...
# 1467  Не происходит фриз (disable) кнопки Send при о...
#
#                                                    stem  cluster_k_means
# 25    инстенс demo ошибка настройка форма представле...               10
# 69     портал каталог услуга проблема клиентский скрипт               10
# 161               формирование обращение каталог услуга               10
# 173     обрезка половина строка карточка каталог портал               10
# 397                         работать фильтрация каталог               10
# 513   долго открываться боковой меню переход прямой ...               10
# 539               открываться каталог услуга ошибка 504               10
# 642                   медленный открытие каталог услуга               10
# 735   ldap авторизация s1 ldap каталог отличный ms a...               10
# 857                       ошибка переход каталог услуга               10
# 903   долгий появление категория каталог услуга sc с...               10
# 916   дефекс вёрстка карточка услуга модель запрос к...               10
# 927   портал каталог услуга работать стрелка назад н...               10
# 932   очень медленно отображаться портал конечный по...               10
# 1012  ошибка поле номер number должный уникальный по...               10
# 1044  возможность выбирать ресурс страница портал на...               10
# 1316  проблема переключение категория каталог услуга...               10
# 1346  пользователь видеть параметр rem зарегистриров...               10
# 1347                   каталог услуга база rem  inquiry               10
# 1462  возникать предупреждение выбор другой тип запр...               10
# 1467  происходить фриз disable кнопка send отправка ...               10

# %% [markdown]
# Попробуем еще один подход к кластеризации.

# %% [markdown]
# ## Hierarchical clustering
#
# Для иерархической кластеризации нужно задать способ подсчета расстояния между объектами и между кластерами. Выберем расстояние Варда (квадрат евклидова расстояния) для подсчета расстояния между кластерами. Евклидово расстояние - между объектами.
#
# *Примечание. Квадрат евклидова расстояния с точки зрения математики не является расстоянием, так как нарушается неравленство треугольника. Но в кластерном анализе у нас задача - измерить схожесть объектов, квадрат евклидова расстояния здесь применим.*

# %%
# Объект, в котором будет хранится информация о последовательном слиянии кластеров
link = linkage(tfidf_matrix.todense(), 'ward', 'euclidean')

# %%
plt.figure(figsize=(20,7))
dn = dendrogram(link)

# %%
cluster_hierarchy_number = 13

# %%
df['cluster_hierarchy'] = fcluster(link, cluster_hierarchy_number, criterion='maxclust')
df
# Out:
#                                                    Тема  \
# 0     Утром опять завис и рестартнул контейнер аттач...
# 1      Задержка в выборке писем из ящика после простоев
# 2               Проблема с отображением Related Tickets
# 3     Некорректное отображение кнопок UI-action на ф...
# 4                            GRPC Server is unavailable
# ...                                                 ...
# 1474        Восстановление доступа на home.simpleone.ru
# 1475     Исходящее письмо обработано со статусом Failed
# 1476  Исходящее письмо обработано со статусом Failed...
# 1477                             Уязвимость на инстансе
# 1478  На продакшн-инстансе, перестали регистрировать...
#
#                                                    stem  cluster_k_means  \
# 0     утром зависнуть рестартнуть контейнер аттач pr...                0
# 1                  задержка выборка письмо ящик простой                9
# 2                  проблема отображение related tickets                3
# 3     некорректный отображение кнопка ui action форм...                8
# 4                            grpc server is unavailable               11
# ...                                                 ...              ...
# 1474              восстановление доступ homesimpleoneru               11
# 1475          исходящий письмо обработать статус failed                9
# 1476  исходящий письмо обработать статус failed запи...                9
# 1477                                 уязвимость инстанс                5
# 1478  продакшн инстанс перестать регистрироваться за...                0
#
#       cluster_hierarchy
# 0                    13
# 1                    11
# 2                    10
# 3                    13
# 4                    13
# ...                 ...
# 1474                 12
# 1475                 11
# 1476                 11
# 1477                  4
# 1478                 13
#
# [1479 rows x 4 columns]

# %% [markdown]
# Посмотрим примеры кластеров:

# %%
df[df.cluster_hierarchy == 4]
# Out:
#                                                    Тема  \
# 241                                 Не работает инстанс
# 242                                 Не работает инстанс
# 243                                 Не работает инстанс
# 244                                 Не работает инстанс
# 248                                        Упал инстанс
# 279   Полная неработоспособность всех инстансов + ht...
# 282                  Низкая производительность инстанса
# 421   Нам пишут, что инстанс уязвим перед атаками cl...
# 455   В облачных и он прем инстансах не настроена ро...
# 499                        не работает SMTP на инстансе
# 863                           Не работает прод-инстанс.
# 969                                       Лежит инстанс
# 970                                 Не доступен инстанс
# 1004  Истечение срока действия сертификата продуктов...
# 1135  Во всех инстансах Itella пропало дефолтное пре...
# 1237           Не работает оператор changes на инстансе
# 1281                              Не доступен инстанс.
# 1337                                Не доступен инстанс
# 1385       Не доступен инстанс ERR_CONNECTION_TIMED_OUT
# 1407                             Уязвимости на инстансе
# 1412                                Инстанс не доступен
# 1477                             Уязвимость на инстансе
#
#                                                    stem  cluster_k_means  \
# 241                                    работать инстанс                5
# 242                                    работать инстанс                5
# 243                                    работать инстанс                5
# 244                                    работать инстанс                5
# 248                                      упасть инстанс                5
# 279   полный неработоспособность инстанс  httpshomes...                5
# 282                   низкий производительность инстанс                5
# 421      мы писать инстанс уязвимый атака click jacking                5
# 455   облачный переть инстанс настроить ротация лог ...                5
# 499                               работать smtp инстанс                5
# 863                               работать прод инстанс                5
# 969                                      лежать инстанс                5
# 970                                   доступный инстанс                5
# 1004  истечение срок действие сертификат продуктовый...                5
# 1135    инстанс itella пропасть дефолтной представление                5
# 1237                  работать оператор changes инстанс                5
# 1281                                  доступный инстанс                5
# 1337                                  доступный инстанс                5
# 1385            доступный инстанс errconnectiontimedout                5
# 1407                                 уязвимость инстанс                5
# 1412                                  инстанс доступный                5
# 1477                                 уязвимость инстанс                5
#
#       cluster_hierarchy
# 241                   4
# 242                   4
# 243                   4
# 244                   4
# 248                   4
# 279                   4
# 282                   4
# 421                   4
# 455                   4
# 499                   4
# 863                   4
# 969                   4
# 970                   4
# 1004                  4
# 1135                  4
# 1237                  4
# 1281                  4
# 1337                  4
# 1385                  4
# 1407                  4
# 1412                  4
# 1477                  4

# %% [markdown]
# # Суммаризация кластеров
#
# MiniBatchKMeans центроиды
#
# Векторизую текст и работаю с векторами

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Преобразование текста в TF-IDF векторы
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['stem'])

# %%
# Кластеризация с MiniBatchKMeans
cluster_number_k_means = 13
k_means_batch = MiniBatchKMeans(n_clusters=cluster_number_k_means, init='random').fit(tfidf_matrix)
labels_k_means_batch = k_means_batch.predict(tfidf_matrix)

# %%
# Добавление меток кластеров к DataFrame
df['cluster_k_means'] = labels_k_means_batch

# %%
# Находим центроиды кластеров
centroids = k_means_batch.cluster_centers_

# %%
vectorizer
# Out:
# TfidfVectorizer(decode_error='ignore', max_df=0.6, max_features=100000,
#                 min_df=0.01, ngram_range=(1, 3))

# %%
# Создаем DataFrame для центроидов
centroids_df = pd.DataFrame(centroids, columns=vectorizer.get_feature_names_out())

# %%
# Выводим центроиды кластеров
print("Centroids:")
print(centroids_df)
# Out:
# Centroids:
#          500  500 cant  500 cant connect       503  503 service  \
# 0   0.284748  0.312686          0.312686  0.000000     0.000000
# 1   0.000000  0.000000          0.000000  0.000000     0.000000
# 2   0.044905  0.000000          0.000000  0.063554     0.000000
# 3   0.018833  0.000000          0.000000  0.000000     0.000000
# 4   0.008048  0.000000          0.000000  0.017974     0.013094
# 5   0.000000  0.000000          0.000000  0.000000     0.000000
# 6   0.000000  0.000000          0.000000  0.000000     0.000000
# 7   0.000000  0.000000          0.000000  0.000000     0.000000
# 8   0.000000  0.000000          0.000000  0.000000     0.000000
# 9   0.000000  0.000000          0.000000  0.000000     0.000000
# 10  0.000000  0.000000          0.000000  0.000000     0.000000
# 11  0.000000  0.000000          0.000000  0.013856     0.000000
# 12  0.000000  0.000000          0.000000  0.000000     0.000000
#
#     503 service unavailable       acl      cant  cant connect  \
# 0                  0.000000  0.000000  0.311275      0.312686
# 1                  0.000000  0.022835  0.000000      0.000000
# 2                  0.000000  0.000000  0.002671      0.000000
# 3                  0.000000  0.002512  0.000000      0.000000
# 4                  0.013094  0.016908  0.000380      0.000000
# 5                  0.000000  0.000000  0.000000      0.000000
# 6                  0.000000  0.023560  0.000000      0.000000
# 7                  0.000000  0.000000  0.000000      0.000000
# 8                  0.000000  0.005684  0.000000      0.000000
# 9                  0.000000  0.000000  0.000000      0.000000
# 10                 0.000000  0.000000  0.000000      0.000000
# 11                 0.000000  0.000000  0.000000      0.000000
# 12                 0.000000  0.000000  0.000000      0.000000
#
#     cant connect to  ...  страница   таблица  тестовый       тип  уведомление  \
# 0          0.312686  ...  0.000000  0.000000  0.000000  0.000000     0.000000
# 1          0.000000  ...  0.008595  0.071394  0.000000  0.045640     0.008807
# 2          0.000000  ...  0.015002  0.000395  0.008237  0.007746     0.007459
# 3          0.000000  ...  0.039259  0.021044  0.006954  0.006768     0.000000
# 4          0.000000  ...  0.019023  0.041705  0.004521  0.005457     0.008776
# 5          0.000000  ...  0.000000  0.000000  0.000000  0.000000     0.000000
# 6          0.000000  ...  0.016124  0.036858  0.000000  0.117071     0.000000
# 7          0.000000  ...  0.000000  0.040789  0.000000  0.078166     0.000000
# 8          0.000000  ...  0.012954  0.000560  0.011956  0.002192     0.018925
# 9          0.000000  ...  0.000000  0.015177  0.000000  0.049752     0.000000
# 10         0.000000  ...  0.037754  0.000000  0.000000  0.007627     0.000000
# 11         0.000000  ...  0.039204  0.001146  0.004249  0.000000     0.000000
# 12         0.000000  ...  0.000000  0.000000  0.000000  0.002507     0.000000
#
#     удаваться   условие    услуга     форма  экземпляр
# 0    0.000000  0.000000  0.000000  0.000000   0.000000
# 1    0.012345  0.000000  0.000000  0.042240   0.000000
# 2    0.001765  0.000000  0.000000  0.023445   0.000000
# 3    0.000000  0.000000  0.000000  0.000000   0.000000
# 4    0.010710  0.004876  0.004324  0.022603   0.003748
# 5    0.000000  0.034594  0.000000  0.000000   0.000000
# 6    0.000000  0.000000  0.000000  0.013934   0.000000
# 7    0.011488  0.000000  0.000000  0.058764   0.000000
# 8    0.006304  0.025673  0.002266  0.006483   0.000000
# 9    0.000000  0.003631  0.000000  0.016337   0.000000
# 10   0.000000  0.000000  0.358476  0.047661   0.000000
# 11   0.010903  0.000000  0.000000  0.013451   0.546304
# 12   0.000000  0.040059  0.000000  0.026008   0.033556
#
# [13 rows x 114 columns]

# %%
# Определим ключевые признаки для каждого кластера
key_features = centroids_df.idxmax(axis=1)

# Создаем словарь, связывающий кластеры с тематиками
cluster_themes = {cluster_id: theme for cluster_id, theme in enumerate(key_features)}

# Выведем результаты
print("Cluster Themes:")
for cluster_id, theme in cluster_themes.items():
    print(f"Cluster {cluster_id}: {theme}")
# Out:
# Cluster Themes:
# Cluster 0: 500 cant
# Cluster 1: поле
# Cluster 2: ошибка
# Cluster 3: работать
# Cluster 4: работа
# Cluster 5: индикация
# Cluster 6: отчёт
# Cluster 7: атрибут
# Cluster 8: скрипт
# Cluster 9: rem
# Cluster 10: каталог
# Cluster 11: экземпляр
# Cluster 12: невозможно

# %%
# Считаем среднее значение по столбцам (центроидам)
centroids_mean = centroids_df.mean()

# Выводим суммаризацию центроидов
print("Mean Centroids:")
print(centroids_mean)
# Out:
# Mean Centroids:
# 500                 0.039990
# 500 cant            0.024084
# 500 cant connect    0.024084
# 503                 0.005894
# 503 service         0.000642
#                       ...
# удаваться           0.001896
# условие             0.053427
# услуга              0.005723
# форма               0.009223
# экземпляр           0.005255
# Length: 114, dtype: float64

# %% [markdown]
# # Тематика группы запросов: автоматически описать тематику группы запросов
#
# Опишем полученные кластера облаком слов:

# %%
def plot_wordcloud(df: pd.DataFrame, max_words=10):
    stopwords = set(STOPWORDS)
    wordcloud = WordCloud(background_color='black',
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = 80,
                    random_state = 42,
                    width=400,
                    height=400)

    # 13 кластеров, по 3 в строку
    fig, axs = plt.subplots(nrows=5, ncols=3, figsize=(20, 40))

    for i in range(5):
      for j in range(3):
        if 3*i+j+1 > 13:
          break

        text = df.stem[df.cluster_k_means == 3*i+j+1]
        title = f'Word Cloud of Query {3*i+j+1}'

        wordcloud.generate(str(text))

        ax = axs[i, j]
        ax.set_axis_off()
        ax.set_title(title, fontdict={'size': 18, 'color': 'black', 'verticalalignment': 'bottom'})
        ax.imshow(wordcloud);

# %%
plot_wordcloud(df)

# %% [markdown]
# Видим в каждом кластере преобладающие слова. По облаку слов становится ясно, о чем идет речь в рамках рассматриваемого кластера.

# %% [markdown]
# # Анализ текста запроса

# %% [markdown]
# ## Natasha
#
# Используем библиотеку Natasha — это набор качественных инструментов для обработки естественного русского языка (сегментация на токены и предложения, предобученные эмбеддинги, анализ морфологии и синтаксиса, лемматизация).
#
# Напишем функцию для выделения имен (причем для наглядности работы библиотеки сделаем сегментацию и лемматизацию средствами библиотеки Natasha)

# %%
segmenter = Segmenter()
emb = NewsEmbedding()

morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

morph_vocab = MorphVocab()
names_extractor = NamesExtractor(morph_vocab)

# %%
def extract_names(text: str):
  doc = Doc(text)

  doc.segment(segmenter)
  doc.tag_morph(morph_tagger)
  doc.parse_syntax(syntax_parser)
  doc.tag_ner(ner_tagger)

  for token in doc.tokens:
    token.lemmatize(morph_vocab)

  for span in doc.spans:
    span.normalize(morph_vocab)

  for span in doc.spans:
    if span.type == PER:
      span.extract_fact(names_extractor)

  return {_.normal: _.fact.as_dict for _ in doc.spans if _.type == PER}

# %% [markdown]
# ## Yargy
#
# Далее найдем аббревиатуры. В случае, когда необходимо создать новое правило для извлечения данных, Yargy-парсер является хорошим решением. Данная библиотека является частью большого проекта Natasha.

# %%
def find_abbreviation(text: str):
  rule_abbrev = rule(dictionary({'кс', 'sas'}))
  parser = Parser(rule_abbrev)

  result = []
  for match in parser.findall(text):
    result.append([x.value for x in match.tokens])

  return result

# %%
df['abbrev'] = df['stem'].apply(find_abbreviation)

# %% [markdown]
# Рассмотрим пример строк с аббревиатурой:

# %%
pip install transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# # Обучение **BERT**

# %%
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
import torch

# Загрузка предобученного токенизатора и модели BERT
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased')

# Предобработка данных
max_length = 256  # Максимальная длина последовательности
batch_size = 16   # Размер батча

# Токенизация текста и преобразование в формат, понятный BERT
tokenized_texts = tokenizer(df['Тема'].tolist(), padding=True, truncation=True, max_length=max_length, return_tensors='pt')

# Создание DataLoader для эффективной обработки батчей
data = torch.utils.data.TensorDataset(tokenized_texts['input_ids'], tokenized_texts['attention_mask'])
loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=False)

# Перевод модели в режим оценки (evaluation mode)
model.eval()

# Генерация тематик
all_topics = []

with torch.no_grad():
    for batch in loader:
        input_ids, attention_mask = batch
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        predicted_labels = torch.argmax(logits, dim=1)
        all_topics.extend(predicted_labels.tolist())

# Добавление предсказанных тем в DataFrame
df['предсказанная_тема'] = all_topics

# Вывод результатов
print(df[['Тема', 'предсказанная_тема']])
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#                                                    Тема  предсказанная_тема
# 0     Утром опять завис и рестартнул контейнер аттач...                   0
# 1      Задержка в выборке писем из ящика после простоев                   0
# 2               Проблема с отображением Related Tickets                   0
# 3     Некорректное отображение кнопок UI-action на ф...                   0
# 4                            GRPC Server is unavailable                   0
# ...                                                 ...                 ...
# 1474        Восстановление доступа на home.simpleone.ru                   0
# 1475     Исходящее письмо обработано со статусом Failed                   0
# 1476  Исходящее письмо обработано со статусом Failed...                   0
# 1477                             Уязвимость на инстансе                   0
# 1478  На продакшн-инстансе, перестали регистрировать...                   0
#
# [1479 rows x 2 columns]

# %%
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from torch.utils.data import DataLoader, TensorDataset
import torch
import pandas as pd

# Подготовка данных
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
encoded_data = tokenizer(df['stem'].tolist(), padding=True, truncation=True, return_tensors='pt', max_length=256)
labels = torch.tensor(df['cluster_k_means'].tolist())

# Определение числа классов (меток)
num_classes = len(df['cluster_k_means'].unique())

# Создание DataLoader
dataset = TensorDataset(encoded_data['input_ids'], encoded_data['attention_mask'], labels)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

# Инициализация модели и оптимизатора
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=num_classes)
optimizer = AdamW(model.parameters(), lr=2e-5)

# Обучение модели
num_epochs = 3
for epoch in range(num_epochs):
    for batch in dataloader:
        input_ids, attention_mask, labels = batch
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


# Сохранение обученной модели
model.save_pretrained("/")
tokenizer.save_pretrained("/")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ('/tokenizer_config.json',
#  '/special_tokens_map.json',
#  '/vocab.txt',
#  '/added_tokens.json')

# %%
torch.save(model, '/saved_model/model.pth')

# %%
torch.save(tokenizer, '/saved_model/tokenizer.pth')

# %%
# # Загрузка предобученного токенизатора и модели BERT
# tokenizer = BertTokenizer.from_pretrained('/tokenizer_config.json')
# model = BertForSequenceClassification.from_pretrained('/model.safetensors')
model = torch.load('/saved_model/model.pth')
tokenizer = torch.load('/saved_model/tokenizer.pth')

# Предобработка данных
max_length = 256  # Максимальная длина последовательности
batch_size = 16   # Размер батча

# Токенизация текста и преобразование в формат, понятный BERT
tokenized_texts = tokenizer(df['stem'].tolist(), padding=True, truncation=True, max_length=max_length, return_tensors='pt')

# Создание DataLoader для эффективной обработки батчей
data = torch.utils.data.TensorDataset(tokenized_texts['input_ids'], tokenized_texts['attention_mask'])
loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=False)

# Перевод модели в режим оценки (evaluation mode)
model.eval()

# Генерация тематик
all_topics = []

with torch.no_grad():
    for batch in loader:
        input_ids, attention_mask = batch
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        predicted_labels = torch.argmax(logits, dim=1)
        all_topics.extend(predicted_labels.tolist())

# Добавление предсказанных тем в DataFrame
df['предсказанная_тема'] = all_topics

# Вывод результатов
print(df[['Тема', 'предсказанная_тема']])
# Out:
#                                                  Тема  предсказанная_тема
# 0   Утром опять завис и рестартнул контейнер аттач...                   0
# 1    Задержка в выборке писем из ящика после простоев                   0
# 2             Проблема с отображением Related Tickets                   9
# 3   Некорректное отображение кнопок UI-action на ф...                   6
# 4                          GRPC Server is unavailable                   0
# 5   Некорректное назначение ролей пользователям гр...                   0
# 6   После деплоя перестали приходить пароли в CI Home                   0
# 7   Не удаётся кастомизировать логотип на админско...                   4
# 8   В листовом представлении доступен переход в ст...                   0
# 9          Не отрабатывает fixedCondition в listitems                   0
# 10                    Пользователи в Employee и Users                   0
# 11                                Виджет для ITSM 1.7                  10
# 12  При обновлении до версии 1.16.0 слетел префикс...                   0
# 13  Некорректно работает смена логотипа на распред...                   4
# 14        Система хранит пароли в открытом виде в ENV                   0
# 15  Проблема с импортом пользователей из AD через ...                   9
# 16                                    Мониторинг PRTG                   0
# 17  При условии advanced во флоу, процесс уходит В...                   0
# 18                    Не редактируется Inbound Action                   0
